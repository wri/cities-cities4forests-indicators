# %%
import ee
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=dTK6fcGRoj-C9iZgZk6HfZkzfP9N6VxLVbvJlzCarMI&tc=vIIABpEH-i-0ihrHoPAjblUIYkcRn1o2ixJBRQIYcJM&cc=8h79t2zxaYGimsR0_6hCY3CGqY_m3Ol0wEbW0Yp5Gxk>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=dTK6fcGRoj-C9iZgZk6HfZkzfP9N6VxLVbvJlzCarMI&tc=vIIABpEH-i-0ihrHoPAjblUIYkcRn1o2ixJBRQIYcJM&cc=8h79t2zxaYGimsR0_6hCY3CGqY_m3Ol0wEbW0Yp5Gxk</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AdQt8qh0OzSlyhwUTXPQ5Ki3GNVoI9y-_Qqhmq6lEg_o4ChQCk3jCLV-9qs
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
import numpy as np
import requests
import os
import pandas as pd
import rasterio
import boto3
import geopandas as gpd
import io
from rasterstats import zonal_stats
import fiona
import rasterio.mask
import geemap
import glob
import boto3

# %%
# hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read input data

# %%
# define directory
out_dir = os.getcwd()
aws_s3_dir = "https://cities-cities4forests.s3.eu-west-3.amazonaws.com/data"

# %%
# read Tree Mosaic Land
tml = ee.ImageCollection('projects/wri-datalab/TML')
tml_tree_cover = tml.reduce(ee.Reducer.mean()).rename('b1')

# %%
# get list of c4f cities
boundary_georef = pd.read_csv('https://cities-cities4forests.s3.eu-west-3.amazonaws.com/data/boundaries/v_0/geo_ref.csv')

# remove cities without tree cover data availability
tml_not_available_cities = ['BRA-Salvador','MEX-Monterrey']
boundary_georef = boundary_georef[~boundary_georef['geo_name'].isin(tml_not_available_cities)].reset_index(drop=True)
boundary_georef
# Out:
#       city_name          geo_name aoi_boundary_name units_boundary_name  \
# 0        Bukavu        COD-Bukavu         ADM3union                ADM3
# 1         Uvira         COD-Uvira         ADM3union                ADM3
# 2   Brazzaville   COG-Brazzaville         ADM4union                ADM4
# 3  Barranquilla  COL-Barranquilla         ADM4union                ADM4
# 4   Addis_Ababa   ETH-Addis_Ababa         ADM4union                ADM4
# 5     Dire_Dawa     ETH-Dire_Dawa         ADM3union                ADM3
# 6       Nairobi       KEN-Nairobi         ADM3union                ADM3
# 7  Antananarivo  MDG-Antananarivo         ADM4union                ADM4
# 8   Mexico_City   MEX-Mexico_City         ADM2union                ADM2
#
#       city_boundary_name country_code geo_level
# 0        COD-Bukavu-ADM2          COD      ADM2
# 1         COD-Uvira-ADM3          COD      ADM3
# 2   COG-Brazzaville-ADM4          COG      ADM4
# 3  COL-Barranquilla-ADM4          COL      ADM4
# 4   ETH-Addis_Ababa-ADM4          ETH      ADM4
# 5     ETH-Dire_Dawa-ADM3          ETH      ADM3
# 6       KEN-Nairobi-ADM3          KEN      ADM3
# 7  MDG-Antananarivo-ADM4          MDG      ADM4
# 8   MEX-Mexico_City-ADM2          MEX      ADM2

# %% [markdown]
# # Compute indicator

# %%
cities_indicators_sicb_11 = pd.DataFrame()

# %%
for i in range(0, len(boundary_georef)):
    print(i)
    geo_name = boundary_georef.loc[i, 'geo_name']
    print("\n geo_name: "+boundary_id_aoi)
    
    boundary_id_aoi = boundary_georef.loc[i, 'geo_name']+'-'+boundary_georef.loc[i, 'aoi_boundary_name']
    boundary_id_unit = boundary_georef.loc[i, 'geo_name']+'-'+boundary_georef.loc[i, 'units_boundary_name']
    
    # process aoi level ------
    print("\n boundary_id_aoi: "+boundary_id_aoi)
    # read boundaries
    boundary_path = aws_s3_dir +'/boundaries/v_0/boundary-'+boundary_id_aoi+'.geojson'
    boundary_geo = requests.get(boundary_path).json()
    boundary_geo_ee = geemap.geojson_to_ee(boundary_geo)
    
    # compute average tml
    tml_mean = tml_tree_cover.reduceRegion(**{
        'reducer': ee.Reducer.mean(),
        'geometry': boundary_geo_ee.geometry(),
        'scale': 10,
        'maxPixels': 1e9
    })
    # get output
    tml_mean_dict = tml_mean.getInfo()
    tml_mean_value = tml_mean_dict['b1']
    
    # store in df and apend
    df = geemap.ee_to_pandas(boundary_geo_ee)
    df['percent_of_tree_cover'] = tml_mean_value
    cities_indicators_sicb_11 = cities_indicators_sicb_11.append(df)
    
    # process unit of analysis level ------
    print("\n boundary_id_unit: "+boundary_id_unit)
    # read boundaries
    boundary_path = aws_s3_dir +'/boundaries/v_0/boundary-'+boundary_id_unit+'.geojson'
    boundary_geo = requests.get(boundary_path).json()
    boundary_geo_ee = geemap.geojson_to_ee(boundary_geo)
    
     # compute average tml
    tml_mean = tml_tree_cover.reduceRegions(**{
        'reducer': ee.Reducer.mean(),
        'collection': boundary_geo_ee,
        'scale': 10
    })
    
    # store output in df and apend
    df = geemap.ee_to_pandas(tml_mean)
    df = df.rename(columns={"mean": "percent_of_tree_cover"})
    cities_indicators_sicb_11 = cities_indicators_sicb_11.append(df)
# Out:
# 0
#
#  geo_name: COG-Brazzaville-ADM4union
#
#  boundary_id_aoi: COD-Bukavu-ADM3union
#
#  boundary_id_unit: COD-Bukavu-ADM3
# 1
#
#  geo_name: COD-Bukavu-ADM3union
#
#  boundary_id_aoi: COD-Uvira-ADM3union
#
#  boundary_id_unit: COD-Uvira-ADM3
# 2
#
#  geo_name: COD-Uvira-ADM3union
#
#  boundary_id_aoi: COG-Brazzaville-ADM4union
#
#  boundary_id_unit: COG-Brazzaville-ADM4
# 3
#
#  geo_name: COG-Brazzaville-ADM4union
#
#  boundary_id_aoi: COL-Barranquilla-ADM4union
#
#  boundary_id_unit: COL-Barranquilla-ADM4
# 4
#
#  geo_name: COL-Barranquilla-ADM4union
#
#  boundary_id_aoi: ETH-Addis_Ababa-ADM4union
#
#  boundary_id_unit: ETH-Addis_Ababa-ADM4
# 5
#
#  geo_name: ETH-Addis_Ababa-ADM4union
#
#  boundary_id_aoi: ETH-Dire_Dawa-ADM3union
#
#  boundary_id_unit: ETH-Dire_Dawa-ADM3
# 6
#
#  geo_name: ETH-Dire_Dawa-ADM3union
#
#  boundary_id_aoi: KEN-Nairobi-ADM3union
#
#  boundary_id_unit: KEN-Nairobi-ADM3
# 7
#
#  geo_name: KEN-Nairobi-ADM3union
#
#  boundary_id_aoi: MDG-Antananarivo-ADM4union
#
#  boundary_id_unit: MDG-Antananarivo-ADM4
# 8
#
#  geo_name: MDG-Antananarivo-ADM4union
#
#  boundary_id_aoi: MEX-Mexico_City-ADM2union
#
#  boundary_id_unit: MEX-Mexico_City-ADM2

# %%
cities_indicators_sicb_11
# Out:
#     geo_parent_name   geo_level creation_date                   geo_id  \
# 0        COD-Bukavu  ADM3-union    2022-08-03  COD-Bukavu_ADM3-union_1
# 0        COD-Bukavu        ADM3    2022-08-03        COD-Bukavu_ADM3_1
# 1        COD-Bukavu        ADM3    2022-08-03        COD-Bukavu_ADM3_2
# 2        COD-Bukavu        ADM3    2022-08-03        COD-Bukavu_ADM3_3
# 0         COD-Uvira  ADM3-union    2022-08-03   COD-Uvira_ADM3-union_1
# ..              ...         ...           ...                      ...
# 71  MEX-Mexico_City        ADM2    2022-08-03  MEX-Mexico_City_ADM2_72
# 72  MEX-Mexico_City        ADM2    2022-08-03  MEX-Mexico_City_ADM2_73
# 73  MEX-Mexico_City        ADM2    2022-08-03  MEX-Mexico_City_ADM2_74
# 74  MEX-Mexico_City        ADM2    2022-08-03  MEX-Mexico_City_ADM2_75
# 75  MEX-Mexico_City        ADM2    2022-08-03  MEX-Mexico_City_ADM2_76
#
#             geo_name  percent_of_tree_cover
# 0         COD-Bukavu              13.268002
# 0             Kadutu              15.544192
# 1             Ibanda              13.512293
# 2             Bagira              12.047980
# 0          COD-Uvira              26.105939
# ..               ...                    ...
# 71       Temascalapa               5.286004
# 72  Tenango del Aire              13.695783
# 73           Texcoco              28.174652
# 74          Tezoyuca               4.707443
# 75         Tonanitla               0.605080
#
# [760 rows x 6 columns]

# %% [markdown]
# # Merge with indicator table

# %%
# read indicator table
cities_indicators = pd.read_csv(aws_s3_dir + '/indicators/cities_indicators.csv') 
cities_indicators.head()
# Out:
#                 geo_id geo_level        geo_name geo_parent_name
# 0  BRA-Salvador_ADM4_1      ADM4         Pituaçu    BRA-Salvador
# 1  BRA-Salvador_ADM4_2      ADM4       Patamares    BRA-Salvador
# 2  BRA-Salvador_ADM4_3      ADM4           Piatã    BRA-Salvador
# 3  BRA-Salvador_ADM4_4      ADM4     Boca do Rio    BRA-Salvador
# 4  BRA-Salvador_ADM4_5      ADM4  Jardim Armação    BRA-Salvador

# %%
def merge_indicators(indicator_table, new_indicator_table, indicator_name):
    if indicator_name in indicator_table.columns:
        print("replace by new indicators")
        indicator_table.drop(indicator_name, inplace=True, axis=1)
        cities_indicators_df = indicator_table.merge(new_indicator_table[["geo_id",indicator_name]], 
                                                     on='geo_id', 
                                                     how='left')
    else:
        print("add new indicators")
        cities_indicators_df = indicator_table.merge(new_indicator_table[["geo_id",indicator_name]], 
                                                     on='geo_id', 
                                                     how='left')
    return(cities_indicators_df)

# %%
cities_indicators_merged = merge_indicators(indicator_table = cities_indicators,
                                            new_indicator_table = cities_indicators_sicb_11,
                                            indicator_name = "percent_of_tree_cover")
# Out:
# add new indicators

# %%
cities_indicators_merged.head()
# Out:
#                 geo_id geo_level        geo_name geo_parent_name  \
# 0  BRA-Salvador_ADM4_1      ADM4         Pituaçu    BRA-Salvador
# 1  BRA-Salvador_ADM4_2      ADM4       Patamares    BRA-Salvador
# 2  BRA-Salvador_ADM4_3      ADM4           Piatã    BRA-Salvador
# 3  BRA-Salvador_ADM4_4      ADM4     Boca do Rio    BRA-Salvador
# 4  BRA-Salvador_ADM4_5      ADM4  Jardim Armação    BRA-Salvador
#
#    percent_of_tree_cover
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %% [markdown]
# # Upload in aws s3

# %%
# connect to s3
aws_credentials = pd.read_csv('C:\\Users\\Saif.Shabou\\OneDrive - World Resources Institute\\Documents\\aws\\credentials.csv')
aws_key = aws_credentials.iloc[0]['Access key ID']
aws_secret = aws_credentials.iloc[0]['Secret access key']

s3 = boto3.resource(
    service_name='s3',
    aws_access_key_id=aws_key,
    aws_secret_access_key=aws_secret
)

# %%
# upload to aws
key_data = 'data/indicators/cities_indicators.csv'
bucket_name = 'cities-cities4forests' 
cities_indicators_merged.to_csv(
    f"s3://{bucket_name}/{key_data}",
    index=False,
    storage_options={
        "key": aws_key,
        "secret": aws_secret
    },
)

# %%
# make it public
object_acl = s3.ObjectAcl(bucket_name,key_data)
response = object_acl.put(ACL='public-read')
